# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto(
    gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction=0.3)
    # device_count = {'GPU': 1}
)
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
set_session(session)
tf.global_variables_initializer().run(session=session)
tf.local_variables_initializer().run(session=session)

# %%
from keras.models import load_model

model = load_model("gz_dev.model")
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 22, 15)       0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 22, 10)       160         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 22, 10)       0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 22, 8)        88          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 22, 8)        0           dense_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 176)          0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          17700       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 20)           3540        flatten_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 100)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 20)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 100)          10100       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 15)           315         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 100)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 15)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100)          10100       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 7)            112         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 100)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 7)            0           dense_8[0][0]
# __________________________________________________________________________________________________
# policy (Dense)                  (None, 925)          93425       leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# value (Dense)                   (None, 1)            8           leaky_re_lu_8[0][0]
# ==================================================================================================
# Total params: 135,548
# Trainable params: 135,548
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
import random
import numpy as np

from trainingHelper import TrainingHelper
from trainingGame import loadTrainingGame
from mapHelper import mapHelper
import nnHelper

from os import listdir
from os.path import isfile, join

filepath = "D:/GalconZero/Games"

TRAINING_CACHE_SUFFIX = ".npz"
TRAINING_GAME_SUFFIX = ".pickle"
BATCH_SIZE = 128 #2048

def createTrainCacheFile(trainingFile):
    trainingGame = loadTrainingGame(trainingFile)
    helper = TrainingHelper(trainingGame)    
    exampleState = trainingGame.states[0]
    mapHelper.setItems(exampleState)
    
    
    trainX = helper.getTrainX()
    trainPolicy, trainValue = helper.getTrainY()
    
    trainingCacheFile = trainingFile.replace(TRAINING_GAME_SUFFIX, TRAINING_CACHE_SUFFIX)
    
    np.savez(trainingCacheFile, trainX=trainX, trainPolicy=trainPolicy, trainValue=trainValue)

def fetchTrainXY(trainingFile):
    trainingCacheFile = trainingFile.replace(TRAINING_GAME_SUFFIX, TRAINING_CACHE_SUFFIX)
    if not isfile(trainingCacheFile):
        createTrainCacheFile(trainingFile)
        
    npzFile = np.load(trainingCacheFile)
#     print('loaded ' + trainingCacheFile)
    return npzFile['trainX'], npzFile['trainPolicy'], npzFile['trainValue']
            
# def getTrainingDataForNumGames(num=-1):
#     onlyFiles = [f for f in listdir(filepath) if isfile(join(filepath, f)) and TRAINING_GAME_SUFFIX in f]
 
#     trainX = np.empty((0, 22, 14))
#     trainY = [np.empty((0, 925)), np.empty((0,))]

#     filenames = onlyFiles if num==-1 else random.sample(onlyFiles, num)
#     for filename in filenames:
#     #     print("loading training file {}".format(filename))
#         nextTrainX, policy, value = fetchTrainXY(filepath + "/" + filename)
        
#         #twice, once for regular, once for flipped Y values
#         trainX = np.concatenate((trainX, nextTrainX))
#         trainX = np.concatenate((trainX, getXAxisReflectedTrainingData(nextTrainX)))

#         #twice, once for regular, once for flipped Y values (reflecting over x axis does not change policy or value)
#         trainY = [np.concatenate((trainY[0], policy)), np.concatenate((trainY[1], value))]
#         trainY = [np.concatenate((trainY[0], policy)), np.concatenate((trainY[1], value))]

#     print("Finished loading {} training files".format(num))
#     return trainX, trainY

def getTrainingDataForNumGames(num=-1):
    onlyFiles = [f for f in listdir(filepath) if isfile(join(filepath, f)) and TRAINING_GAME_SUFFIX in f]
 
    NUM_VALIDATION_FILES = 10
    
    valTrainX = []
    valYPolicy = []
    valYValue = []
    trainX = []
    trainPolicy = []
    trainValue = []
    
    # reserve 20 games worth of files for validation only
    validationFilenames = onlyFiles[len(onlyFiles) - NUM_VALIDATION_FILES:]
    for filename in validationFilenames:
    #     print("loading training file {}".format(filename))
        nextTrainX, policy, value = fetchTrainXY(filepath + "/" + filename)
        
        #twice, once for regular, once for flipped Y values
        valTrainX.extend(nextTrainX)
        valTrainX.extend(getXAxisReflectedTrainingData(nextTrainX))

        #twice, once for regular, once for flipped Y values (reflecting over x axis does not change policy or value)
        valYPolicy.extend(policy)
        valYPolicy.extend(policy)
        valYValue.extend(value)
        valYValue.extend(value)
    
    
    
    trainFilenames = onlyFiles[:len(onlyFiles) - NUM_VALIDATION_FILES]
    
    filenames = trainFilenames if num==-1 else random.sample(trainFilenames, num)
    for filename in filenames:
    #     print("loading training file {}".format(filename))
        nextTrainX, policy, value = fetchTrainXY(filepath + "/" + filename)
        
        #twice, once for regular, once for flipped Y values
        trainX.extend(nextTrainX)
        trainX.extend(getXAxisReflectedTrainingData(nextTrainX))

        #twice, once for regular, once for flipped Y values (reflecting over x axis does not change policy or value)
        trainPolicy.extend(policy)
        trainPolicy.extend(policy)
        trainValue.extend(value)
        trainValue.extend(value)

    valTrainX = np.array(valTrainX[::10])
    valYPolicy = np.array(valYPolicy[::10])
    valYValue = np.array(valYValue[::10])
    trainX = np.array(trainX)
    trainPolicy = np.array(trainPolicy)
    trainValue = np.array(trainValue)
    
    print("Finished loading {} training files and {} validation files".format(len(filenames), len(validationFilenames)))
    return trainX, [trainPolicy, trainValue], valTrainX, [valYPolicy, valYValue]

def trainingLoop(numGamesPerLoop, numEpochs):
    trainX, [trainYPolicy, trainYValue], valTrainX, [valYPolicy, valYValue] = getTrainingDataForNumGames(numGamesPerLoop)
    
    indices = np.arange(len(trainX))
    randomSubsetIndices = np.random.choice(indices, size=int(len(trainX)/10), replace=False)
    
    trainX = np.take(trainX, randomSubsetIndices, axis=0)
    trainYPolicy = np.take(trainYPolicy, randomSubsetIndices, axis=0)  
    trainYValue = np.take(trainYValue, randomSubsetIndices, axis=0)
    
    return model.fit(trainX, [trainYPolicy, trainYValue], validation_data=(valTrainX, [valYPolicy, valYValue]), epochs=numEpochs, shuffle=True, batch_size=BATCH_SIZE)

def getXAxisReflectedTrainingData(data):
    data = data.copy()
    for sample in data:
        for row in sample:
            row[8] *= -1
            row[11] *= -1
            row[14] *= -1
    return data

# %%
historyPolicyValAcc = []
historyValueValAcc = []

historyPolicyValLoss = []
historyValueValLoss = []
historyValLoss = []

def doTrain(num_loops, numGamesPerLoop,numEpochs=1):
    for i in range(num_loops):
        history = trainingLoop(numGamesPerLoop, numEpochs)

        historyPolicyValAcc.extend(history.history['val_policy_acc'])
        historyValueValAcc.extend(history.history['val_value_acc'])
        
        historyPolicyValLoss.extend(history.history['val_policy_loss'])
        historyValueValLoss.extend(history.history['val_value_loss'])
        historyValLoss.extend(history.history['val_loss'])

# %%
# import tensorflow as tf

# doTrain(num_loops=1000, numGamesPerLoop=100)

# for some dumb reason, I have to do this suddenly
# with tf.Session() as sess:
#     sess.run(tf.global_variables_initializer())
    # for some dumb reason, this fails the first time
doTrain(num_loops=100, numGamesPerLoop=20,numEpochs=1)
# Out:
# Finished loading 20 training files and 10 validation files
# Train on 1082 samples, validate on 478 samples
# Epoch 1/1
# 1082/1082 [==============================] - 0s 112us/step - loss: 10.0415 - policy_loss: 3.5222 - value_loss: 0.6519 - policy_acc: 0.2532 - value_acc: 0.6054 - val_loss: 11.5917 - val_policy_loss: 4.7759 - val_value_loss: 0.6816 - val_policy_acc: 0.0314 - val_value_acc: 0.5669
# Finished loading 20 training files and 10 validation files
# Train on 1026 samples, validate on 428 samples
# Epoch 1/1
# 1026/1026 [==============================] - 0s 107us/step - loss: 9.7140 - policy_loss: 3.7794 - value_loss: 0.5935 - policy_acc: 0.2222 - value_acc: 0.6501 - val_loss: 12.0404 - val_policy_loss: 4.3059 - val_value_loss: 0.7735 - val_policy_acc: 0.0841 - val_value_acc: 0.4766
# Finished loading 20 training files and 10 validation files
# Train on 1080 samples, validate on 307 samples
# Epoch 1/1
# 1080/1080 [==============================] - 0s 99us/step - loss: 9.2621 - policy_loss: 3.2572 - value_loss: 0.6005 - policy_acc: 0.2676 - value_acc: 0.6352 - val_loss: 10.4805 - val_policy_loss: 4.5624 - val_value_loss: 0.5918 - val_policy_acc: 0.0879 - val_value_acc: 0.6156
# Finished loading 20 training files and 10 validation files
# Train on 1062 samples, validate on 307 samples
# Epoch 1/1
# 1062/1062 [==============================] - 0s 100us/step - loss: 9.5868 - policy_loss: 3.7233 - value_loss: 0.5864 - policy_acc: 0.1883 - value_acc: 0.6497 - val_loss: 10.7284 - val_policy_loss: 4.6715 - val_value_loss: 0.6057 - val_policy_acc: 0.0717 - val_value_acc: 0.6026
# Finished loading 20 training files and 10 validation files
# Train on 1101 samples, validate on 401 samples
# Epoch 1/1
# 1101/1101 [==============================] - 0s 103us/step - loss: 9.6844 - policy_loss: 3.4088 - value_loss: 0.6276 - policy_acc: 0.2307 - value_acc: 0.5822 - val_loss: 9.5408 - val_policy_loss: 3.3612 - val_value_loss: 0.6180 - val_policy_acc: 0.2893 - val_value_acc: 0.6259
# Finished loading 20 training files and 10 validation files
# Train on 1046 samples, validate on 482 samples
# Epoch 1/1
# 1046/1046 [==============================] - 0s 105us/step - loss: 8.9900 - policy_loss: 3.6264 - value_loss: 0.5364 - policy_acc: 0.2008 - value_acc: 0.7486 - val_loss: 10.2086 - val_policy_loss: 3.6923 - val_value_loss: 0.6516 - val_policy_acc: 0.2469 - val_value_acc: 0.5975
# Finished loading 20 training files and 10 validation files
# Train on 1164 samples, validate on 562 samples
# Epoch 1/1
# 1164/1164 [==============================] - 0s 128us/step - loss: 9.3147 - policy_loss: 3.6192 - value_loss: 0.5696 - policy_acc: 0.2466 - value_acc: 0.6443 - val_loss: 10.0994 - val_policy_loss: 3.5206 - val_value_loss: 0.6579 - val_policy_acc: 0.2260 - val_value_acc: 0.5943
# Finished loading 20 training files and 10 validation files
# Train on 1067 samples, validate on 562 samples
# Epoch 1/1
# 1067/1067 [==============================] - 0s 110us/step - loss: 10.1916 - policy_loss: 3.4093 - value_loss: 0.6782 - policy_acc: 0.2240 - value_acc: 0.5548 - val_loss: 10.9239 - val_policy_loss: 3.8407 - val_value_loss: 0.7083 - val_policy_acc: 0.2064 - val_value_acc: 0.5943
# Finished loading 20 training files and 10 validation files
# Train on 1061 samples, validate on 562 samples
# Epoch 1/1
# 1061/1061 [==============================] - 0s 106us/step - loss: 9.8877 - policy_loss: 3.5255 - value_loss: 0.6362 - policy_acc: 0.2196 - value_acc: 0.5815 - val_loss: 11.1087 - val_policy_loss: 4.3029 - val_value_loss: 0.6806 - val_policy_acc: 0.0249 - val_value_acc: 0.5587
# Finished loading 20 training files and 10 validation files
# Train on 1020 samples, validate on 562 samples
# Epoch 1/1
# 1020/1020 [==============================] - 0s 107us/step - loss: 9.3359 - policy_loss: 3.5098 - value_loss: 0.5826 - policy_acc: 0.2520 - value_acc: 0.6382 - val_loss: 10.7700 - val_policy_loss: 3.4887 - val_value_loss: 0.7281 - val_policy_acc: 0.2117 - val_value_acc: 0.5125
# Finished loading 20 training files and 10 validation files
# Train on 1125 samples, validate on 574 samples
# Epoch 1/1
# 1125/1125 [==============================] - 0s 105us/step - loss: 9.7418 - policy_loss: 2.9225 - value_loss: 0.6819 - policy_acc: 0.3511 - value_acc: 0.5822 - val_loss: 10.6555 - val_policy_loss: 3.6030 - val_value_loss: 0.7053 - val_policy_acc: 0.1847 - val_value_acc: 0.5192
# Finished loading 20 training files and 10 validation files
# Train on 1093 samples, validate on 557 samples
# Epoch 1/1
# 1093/1093 [==============================] - 0s 102us/step - loss: 8.7140 - policy_loss: 3.3602 - value_loss: 0.5354 - policy_acc: 0.2086 - value_acc: 0.7347 - val_loss: 10.7339 - val_policy_loss: 3.2198 - val_value_loss: 0.7514 - val_policy_acc: 0.2208 - val_value_acc: 0.5476
# Finished loading 20 training files and 10 validation files
# Train on 1114 samples, validate on 557 samples
# Epoch 1/1
# 1114/1114 [==============================] - 0s 104us/step - loss: 10.3946 - policy_loss: 3.0902 - value_loss: 0.7304 - policy_acc: 0.2612 - value_acc: 0.5063 - val_loss: 9.6051 - val_policy_loss: 3.1122 - val_value_loss: 0.6493 - val_policy_acc: 0.2729 - val_value_acc: 0.6050
# Finished loading 20 training files and 10 validation files
# Train on 1019 samples, validate on 557 samples
# Epoch 1/1
# 1019/1019 [==============================] - 0s 106us/step - loss: 9.1564 - policy_loss: 3.0560 - value_loss: 0.6100 - policy_acc: 0.3003 - value_acc: 0.6389 - val_loss: 9.1928 - val_policy_loss: 3.1540 - val_value_loss: 0.6039 - val_policy_acc: 0.3268 - val_value_acc: 0.5925
# Finished loading 20 training files and 10 validation files
# Train on 1055 samples, validate on 533 samples
# Epoch 1/1
# 1055/1055 [==============================] - 0s 111us/step - loss: 9.1391 - policy_loss: 2.9421 - value_loss: 0.6197 - policy_acc: 0.3336 - value_acc: 0.5981 - val_loss: 9.4781 - val_policy_loss: 3.4987 - val_value_loss: 0.5979 - val_policy_acc: 0.2495 - val_value_acc: 0.6473
# Finished loading 20 training files and 10 validation files
# Train on 1003 samples, validate on 550 samples
# Epoch 1/1
# 1003/1003 [==============================] - 0s 107us/step - loss: 9.1974 - policy_loss: 3.1916 - value_loss: 0.6006 - policy_acc: 0.2692 - value_acc: 0.6580 - val_loss: 9.7907 - val_policy_loss: 2.7713 - val_value_loss: 0.7019 - val_policy_acc: 0.3455 - val_value_acc: 0.5855
# Finished loading 20 training files and 10 validation files
# Train on 1091 samples, validate on 520 samples
# Epoch 1/1
# 1091/1091 [==============================] - 0s 107us/step - loss: 8.3560 - policy_loss: 2.7809 - value_loss: 0.5575 - policy_acc: 0.3685 - value_acc: 0.7012 - val_loss: 9.1408 - val_policy_loss: 3.1384 - val_value_loss: 0.6002 - val_policy_acc: 0.2981 - val_value_acc: 0.6731
# Finished loading 20 training files and 10 validation files
# Train on 1151 samples, validate on 468 samples
# Epoch 1/1
# 1151/1151 [==============================] - 0s 97us/step - loss: 9.3599 - policy_loss: 2.8968 - value_loss: 0.6463 - policy_acc: 0.3301 - value_acc: 0.5908 - val_loss: 8.7030 - val_policy_loss: 3.3012 - val_value_loss: 0.5402 - val_policy_acc: 0.2137 - val_value_acc: 0.7009
# Finished loading 20 training files and 10 validation files
# Train on 1038 samples, validate on 468 samples
# Epoch 1/1
# 1038/1038 [==============================] - 0s 118us/step - loss: 8.9564 - policy_loss: 3.1672 - value_loss: 0.5789 - policy_acc: 0.2572 - value_acc: 0.6590 - val_loss: 9.1188 - val_policy_loss: 3.5588 - val_value_loss: 0.5560 - val_policy_acc: 0.2286 - val_value_acc: 0.6581
# Finished loading 20 training files and 10 validation files
# Train on 1101 samples, validate on 474 samples
# Epoch 1/1
# 1101/1101 [==============================] - 0s 104us/step - loss: 9.0421 - policy_loss: 3.5423 - value_loss: 0.5500 - policy_acc: 0.2116 - value_acc: 0.7193 - val_loss: 8.8235 - val_policy_loss: 3.5092 - val_value_loss: 0.5314 - val_policy_acc: 0.1730 - val_value_acc: 0.6751
# Finished loading 20 training files and 10 validation files
# Train on 1046 samples, validate on 483 samples
# Epoch 1/1
# 1046/1046 [==============================] - 0s 103us/step - loss: 8.8896 - policy_loss: 3.0306 - value_loss: 0.5859 - policy_acc: 0.2514 - value_acc: 0.6931 - val_loss: 9.0212 - val_policy_loss: 3.5582 - val_value_loss: 0.5463 - val_policy_acc: 0.1573 - val_value_acc: 0.6625
# Finished loading 20 training files and 10 validation files
# Train on 1134 samples, validate on 505 samples
# Epoch 1/1
# 1134/1134 [==============================] - 0s 101us/step - loss: 8.7056 - policy_loss: 2.6665 - value_loss: 0.6039 - policy_acc: 0.3351 - value_acc: 0.6755 - val_loss: 9.2360 - val_policy_loss: 3.9335 - val_value_loss: 0.5302 - val_policy_acc: 0.1446 - val_value_acc: 0.6792
# Finished loading 20 training files and 10 validation files
# Train on 1074 samples, validate on 505 samples
# Epoch 1/1
# 1074/1074 [==============================] - 0s 111us/step - loss: 9.2854 - policy_loss: 3.1581 - value_loss: 0.6127 - policy_acc: 0.2561 - value_acc: 0.6583 - val_loss: 8.6763 - val_policy_loss: 3.3745 - val_value_loss: 0.5302 - val_policy_acc: 0.3267 - val_value_acc: 0.6752
# Finished loading 20 training files and 10 validation files
# Train on 1088 samples, validate on 505 samples
# Epoch 1/1
# 1088/1088 [==============================] - 0s 103us/step - loss: 8.5325 - policy_loss: 3.1691 - value_loss: 0.5363 - policy_acc: 0.2647 - value_acc: 0.7252 - val_loss: 9.0559 - val_policy_loss: 3.2222 - val_value_loss: 0.5834 - val_policy_acc: 0.2931 - val_value_acc: 0.6396
# Finished loading 20 training files and 10 validation files
# Train on 1100 samples, validate on 549 samples
# Epoch 1/1
# 1100/1100 [==============================] - 0s 108us/step - loss: 9.9522 - policy_loss: 2.8910 - value_loss: 0.7061 - policy_acc: 0.2764 - value_acc: 0.5336 - val_loss: 8.6737 - val_policy_loss: 3.1784 - val_value_loss: 0.5495 - val_policy_acc: 0.3297 - val_value_acc: 0.6849
# Finished loading 20 training files and 10 validation files
# Train on 977 samples, validate on 523 samples
# Epoch 1/1
# 977/977 [==============================] - 0s 120us/step - loss: 9.1530 - policy_loss: 3.4402 - value_loss: 0.5713 - policy_acc: 0.2518 - value_acc: 0.6919 - val_loss: 9.5065 - val_policy_loss: 3.5479 - val_value_loss: 0.5959 - val_policy_acc: 0.2294 - val_value_acc: 0.6673
# Finished loading 20 training files and 10 validation files
# Train on 1093 samples, validate on 553 samples
# Epoch 1/1
# 1093/1093 [==============================] - 0s 115us/step - loss: 9.7648 - policy_loss: 3.1049 - value_loss: 0.6660 - policy_acc: 0.2132 - value_acc: 0.5682 - val_loss: 9.1079 - val_policy_loss: 3.4478 - val_value_loss: 0.5660 - val_policy_acc: 0.1103 - val_value_acc: 0.6727
# Finished loading 20 training files and 10 validation files
# Train on 1092 samples, validate on 553 samples
# Epoch 1/1
# 1092/1092 [==============================] - 0s 104us/step - loss: 8.4441 - policy_loss: 2.6827 - value_loss: 0.5761 - policy_acc: 0.3086 - value_acc: 0.6941 - val_loss: 10.1248 - val_policy_loss: 3.5555 - val_value_loss: 0.6569 - val_policy_acc: 0.1465 - val_value_acc: 0.5913
# Finished loading 20 training files and 10 validation files
# Train on 859 samples, validate on 553 samples
# Epoch 1/1
# 859/859 [==============================] - 0s 114us/step - loss: 10.5810 - policy_loss: 3.1416 - value_loss: 0.7439 - policy_acc: 0.2456 - value_acc: 0.5064 - val_loss: 9.9508 - val_policy_loss: 4.2148 - val_value_loss: 0.5736 - val_policy_acc: 0.0958 - val_value_acc: 0.6709
# Finished loading 20 training files and 10 validation files
# Train on 1121 samples, validate on 553 samples
# Epoch 1/1
# 1121/1121 [==============================] - 0s 105us/step - loss: 9.2011 - policy_loss: 2.8396 - value_loss: 0.6361 - policy_acc: 0.2846 - value_acc: 0.5745 - val_loss: 9.6883 - val_policy_loss: 3.6747 - val_value_loss: 0.6014 - val_policy_acc: 0.2170 - val_value_acc: 0.6492
# Finished loading 20 training files and 10 validation files
# Train on 973 samples, validate on 593 samples
# Epoch 1/1
# 973/973 [==============================] - 0s 107us/step - loss: 8.9982 - policy_loss: 3.1117 - value_loss: 0.5887 - policy_acc: 0.2960 - value_acc: 0.6650 - val_loss: 9.7254 - val_policy_loss: 3.2653 - val_value_loss: 0.6460 - val_policy_acc: 0.2563 - val_value_acc: 0.5902
# Finished loading 20 training files and 10 validation files
# Train on 1073 samples, validate on 593 samples
# Epoch 1/1
# 1073/1073 [==============================] - 0s 105us/step - loss: 9.1510 - policy_loss: 3.2577 - value_loss: 0.5893 - policy_acc: 0.2330 - value_acc: 0.6440 - val_loss: 10.2693 - val_policy_loss: 3.4507 - val_value_loss: 0.6819 - val_policy_acc: 0.1669 - val_value_acc: 0.5548
# Finished loading 20 training files and 10 validation files
# Train on 1127 samples, validate on 593 samples
# Epoch 1/1
# 1127/1127 [==============================] - 0s 110us/step - loss: 9.3770 - policy_loss: 2.7711 - value_loss: 0.6606 - policy_acc: 0.2999 - value_acc: 0.5475 - val_loss: 9.4438 - val_policy_loss: 3.4250 - val_value_loss: 0.6019 - val_policy_acc: 0.1686 - val_value_acc: 0.6492
# Finished loading 20 training files and 10 validation files
# Train on 1016 samples, validate on 593 samples
# Epoch 1/1
# 1016/1016 [==============================] - 0s 105us/step - loss: 8.7333 - policy_loss: 2.7269 - value_loss: 0.6006 - policy_acc: 0.3140 - value_acc: 0.6545 - val_loss: 9.7971 - val_policy_loss: 3.0406 - val_value_loss: 0.6756 - val_policy_acc: 0.2732 - val_value_acc: 0.5548
# Finished loading 20 training files and 10 validation files
# Train on 1080 samples, validate on 593 samples
# Epoch 1/1
# 1080/1080 [==============================] - 0s 111us/step - loss: 9.5607 - policy_loss: 2.9889 - value_loss: 0.6572 - policy_acc: 0.2583 - value_acc: 0.5935 - val_loss: 9.5149 - val_policy_loss: 2.9469 - val_value_loss: 0.6568 - val_policy_acc: 0.3221 - val_value_acc: 0.5700
# Finished loading 20 training files and 10 validation files
# Train on 1008 samples, validate on 593 samples
# Epoch 1/1
# 1008/1008 [==============================] - 0s 111us/step - loss: 8.8985 - policy_loss: 2.6616 - value_loss: 0.6237 - policy_acc: 0.3145 - value_acc: 0.6151 - val_loss: 9.1828 - val_policy_loss: 2.9733 - val_value_loss: 0.6209 - val_policy_acc: 0.2479 - val_value_acc: 0.6678
# Finished loading 20 training files and 10 validation files
# Train on 1074 samples, validate on 600 samples
# Epoch 1/1
# 1074/1074 [==============================] - 0s 108us/step - loss: 8.6541 - policy_loss: 2.6493 - value_loss: 0.6005 - policy_acc: 0.3119 - value_acc: 0.6667 - val_loss: 10.1628 - val_policy_loss: 3.3309 - val_value_loss: 0.6832 - val_policy_acc: 0.2200 - val_value_acc: 0.5617
# Finished loading 20 training files and 10 validation files
# Train on 1092 samples, validate on 600 samples
# Epoch 1/1
# 1092/1092 [==============================] - 0s 108us/step - loss: 8.8979 - policy_loss: 2.9194 - value_loss: 0.5978 - policy_acc: 0.4066 - value_acc: 0.5934 - val_loss: 10.3418 - val_policy_loss: 3.5078 - val_value_loss: 0.6834 - val_policy_acc: 0.1700 - val_value_acc: 0.5700
# Finished loading 20 training files and 10 validation files
# Train on 1138 samples, validate on 600 samples
# Epoch 1/1
# 1138/1138 [==============================] - 0s 105us/step - loss: 8.5904 - policy_loss: 2.5733 - value_loss: 0.6017 - policy_acc: 0.3735 - value_acc: 0.6714 - val_loss: 10.4223 - val_policy_loss: 3.5644 - val_value_loss: 0.6858 - val_policy_acc: 0.1783 - val_value_acc: 0.5850
# Finished loading 20 training files and 10 validation files
# Train on 959 samples, validate on 600 samples
# Epoch 1/1
# 959/959 [==============================] - 0s 114us/step - loss: 8.4975 - policy_loss: 2.7907 - value_loss: 0.5707 - policy_acc: 0.2930 - value_acc: 0.6340 - val_loss: 10.6323 - val_policy_loss: 3.9168 - val_value_loss: 0.6715 - val_policy_acc: 0.0983 - val_value_acc: 0.5733
# Finished loading 20 training files and 10 validation files
# Train on 1171 samples, validate on 600 samples
# Epoch 1/1
# 1171/1171 [==============================] - 0s 118us/step - loss: 8.9331 - policy_loss: 2.7126 - value_loss: 0.6220 - policy_acc: 0.2724 - value_acc: 0.6422 - val_loss: 10.5764 - val_policy_loss: 3.5782 - val_value_loss: 0.6998 - val_policy_acc: 0.1717 - val_value_acc: 0.5317
# Finished loading 20 training files and 10 validation files
# Train on 1146 samples, validate on 600 samples
# Epoch 1/1
# 1146/1146 [==============================] - 0s 106us/step - loss: 8.6434 - policy_loss: 2.6477 - value_loss: 0.5996 - policy_acc: 0.3665 - value_acc: 0.6082 - val_loss: 10.4933 - val_policy_loss: 3.6879 - val_value_loss: 0.6805 - val_policy_acc: 0.1950 - val_value_acc: 0.5483
# Finished loading 20 training files and 10 validation files
# Train on 1082 samples, validate on 600 samples
# Epoch 1/1
# 1082/1082 [==============================] - 0s 110us/step - loss: 9.6045 - policy_loss: 2.9111 - value_loss: 0.6693 - policy_acc: 0.2763 - value_acc: 0.5166 - val_loss: 10.5951 - val_policy_loss: 3.7755 - val_value_loss: 0.6820 - val_policy_acc: 0.1133 - val_value_acc: 0.5450
# Finished loading 20 training files and 10 validation files
# Train on 1116 samples, validate on 600 samples
# Epoch 1/1
# 1116/1116 [==============================] - 0s 115us/step - loss: 8.7973 - policy_loss: 2.5017 - value_loss: 0.6296 - policy_acc: 0.3235 - value_acc: 0.6272 - val_loss: 10.4696 - val_policy_loss: 3.7298 - val_value_loss: 0.6740 - val_policy_acc: 0.1400 - val_value_acc: 0.5550
# Finished loading 20 training files and 10 validation files
# Train on 1012 samples, validate on 556 samples
# Epoch 1/1
# 1012/1012 [==============================] - 0s 103us/step - loss: 8.9270 - policy_loss: 2.6913 - value_loss: 0.6236 - policy_acc: 0.3162 - value_acc: 0.6522 - val_loss: 9.8253 - val_policy_loss: 3.4235 - val_value_loss: 0.6402 - val_policy_acc: 0.1655 - val_value_acc: 0.5935
# Finished loading 20 training files and 10 validation files
# Train on 1083 samples, validate on 556 samples
# Epoch 1/1
# 1083/1083 [==============================] - 0s 115us/step - loss: 9.2000 - policy_loss: 3.0094 - value_loss: 0.6191 - policy_acc: 0.2807 - value_acc: 0.6316 - val_loss: 9.4234 - val_policy_loss: 3.2053 - val_value_loss: 0.6218 - val_policy_acc: 0.1601 - val_value_acc: 0.6205
# Finished loading 20 training files and 10 validation files
# Train on 1151 samples, validate on 529 samples
# Epoch 1/1
# 1151/1151 [==============================] - 0s 101us/step - loss: 8.3209 - policy_loss: 2.2951 - value_loss: 0.6026 - policy_acc: 0.4283 - value_acc: 0.6368 - val_loss: 9.0942 - val_policy_loss: 3.3748 - val_value_loss: 0.5719 - val_policy_acc: 0.1645 - val_value_acc: 0.6994
# Finished loading 20 training files and 10 validation files
# Train on 1102 samples, validate on 529 samples
# Epoch 1/1
# 1102/1102 [==============================] - 0s 103us/step - loss: 7.8634 - policy_loss: 2.5335 - value_loss: 0.5330 - policy_acc: 0.3303 - value_acc: 0.7650 - val_loss: 9.2449 - val_policy_loss: 3.3445 - val_value_loss: 0.5900 - val_policy_acc: 0.1947 - val_value_acc: 0.6238
# Finished loading 20 training files and 10 validation files
# Train on 1112 samples, validate on 470 samples
# Epoch 1/1
# 1112/1112 [==============================] - 0s 115us/step - loss: 9.0518 - policy_loss: 2.8221 - value_loss: 0.6230 - policy_acc: 0.3040 - value_acc: 0.6475 - val_loss: 9.2494 - val_policy_loss: 3.4384 - val_value_loss: 0.5811 - val_policy_acc: 0.1489 - val_value_acc: 0.6404
# Finished loading 20 training files and 10 validation files
# Train on 1102 samples, validate on 448 samples
# Epoch 1/1
# 1102/1102 [==============================] - 0s 100us/step - loss: 9.3358 - policy_loss: 2.7924 - value_loss: 0.6543 - policy_acc: 0.3040 - value_acc: 0.5472 - val_loss: 8.9721 - val_policy_loss: 3.3467 - val_value_loss: 0.5625 - val_policy_acc: 0.1652 - val_value_acc: 0.6875
# Finished loading 20 training files and 10 validation files
# Train on 1137 samples, validate on 448 samples
# Epoch 1/1
# 1137/1137 [==============================] - 0s 101us/step - loss: 8.0966 - policy_loss: 2.6142 - value_loss: 0.5482 - policy_acc: 0.3017 - value_acc: 0.6983 - val_loss: 8.9631 - val_policy_loss: 2.5474 - val_value_loss: 0.6416 - val_policy_acc: 0.3326 - val_value_acc: 0.5871
# Finished loading 20 training files and 10 validation files
# Train on 1122 samples, validate on 459 samples
# Epoch 1/1
# 1122/1122 [==============================] - 0s 101us/step - loss: 9.6088 - policy_loss: 2.9313 - value_loss: 0.6677 - policy_acc: 0.2888 - value_acc: 0.5686 - val_loss: 8.5606 - val_policy_loss: 2.7701 - val_value_loss: 0.5791 - val_policy_acc: 0.3224 - val_value_acc: 0.6514
# Finished loading 20 training files and 10 validation files
# Train on 1094 samples, validate on 459 samples
# Epoch 1/1
# 1094/1094 [==============================] - 0s 118us/step - loss: 9.3050 - policy_loss: 2.7417 - value_loss: 0.6563 - policy_acc: 0.2486 - value_acc: 0.5923 - val_loss: 8.7623 - val_policy_loss: 2.9535 - val_value_loss: 0.5809 - val_policy_acc: 0.2898 - val_value_acc: 0.6536
# Finished loading 20 training files and 10 validation files
# Train on 1157 samples, validate on 519 samples
# Epoch 1/1
# 1157/1157 [==============================] - 0s 106us/step - loss: 8.9946 - policy_loss: 2.6492 - value_loss: 0.6345 - policy_acc: 0.3302 - value_acc: 0.6258 - val_loss: 8.9871 - val_policy_loss: 2.7215 - val_value_loss: 0.6266 - val_policy_acc: 0.2755 - val_value_acc: 0.6050
# Finished loading 20 training files and 10 validation files
# Train on 932 samples, validate on 564 samples
# Epoch 1/1
# 932/932 [==============================] - 0s 117us/step - loss: 8.6734 - policy_loss: 2.8201 - value_loss: 0.5853 - policy_acc: 0.2865 - value_acc: 0.6309 - val_loss: 8.6088 - val_policy_loss: 2.9556 - val_value_loss: 0.5653 - val_policy_acc: 0.2730 - val_value_acc: 0.6720
# Finished loading 20 training files and 10 validation files
# Train on 1162 samples, validate on 564 samples
# Epoch 1/1
# 1162/1162 [==============================] - 0s 108us/step - loss: 8.1718 - policy_loss: 2.1802 - value_loss: 0.5992 - policy_acc: 0.4079 - value_acc: 0.6601 - val_loss: 8.8809 - val_policy_loss: 2.9251 - val_value_loss: 0.5956 - val_policy_acc: 0.2287 - val_value_acc: 0.6330
# Finished loading 20 training files and 10 validation files
# Train on 1029 samples, validate on 564 samples
# Epoch 1/1
# 1029/1029 [==============================] - 0s 115us/step - loss: 8.8811 - policy_loss: 2.9424 - value_loss: 0.5939 - policy_acc: 0.2653 - value_acc: 0.6725 - val_loss: 9.0563 - val_policy_loss: 3.2479 - val_value_loss: 0.5808 - val_policy_acc: 0.1560 - val_value_acc: 0.6436
# Finished loading 20 training files and 10 validation files
# Train on 1072 samples, validate on 520 samples
# Epoch 1/1
# 1072/1072 [==============================] - 0s 105us/step - loss: 8.0661 - policy_loss: 2.3039 - value_loss: 0.5762 - policy_acc: 0.3993 - value_acc: 0.6716 - val_loss: 8.4476 - val_policy_loss: 2.8745 - val_value_loss: 0.5573 - val_policy_acc: 0.2808 - val_value_acc: 0.6712
# Finished loading 20 training files and 10 validation files
# Train on 1048 samples, validate on 520 samples
# Epoch 1/1
# 1048/1048 [==============================] - 0s 113us/step - loss: 8.1815 - policy_loss: 2.8517 - value_loss: 0.5330 - policy_acc: 0.3006 - value_acc: 0.7176 - val_loss: 8.7550 - val_policy_loss: 3.0775 - val_value_loss: 0.5677 - val_policy_acc: 0.2288 - val_value_acc: 0.6615
# Finished loading 20 training files and 10 validation files
# Train on 1034 samples, validate on 451 samples
# Epoch 1/1
# 1034/1034 [==============================] - 0s 109us/step - loss: 8.8940 - policy_loss: 2.7820 - value_loss: 0.6112 - policy_acc: 0.3027 - value_acc: 0.6509 - val_loss: 8.7384 - val_policy_loss: 3.3317 - val_value_loss: 0.5407 - val_policy_acc: 0.1907 - val_value_acc: 0.6829
# Finished loading 20 training files and 10 validation files
# Train on 1141 samples, validate on 472 samples
# Epoch 1/1
# 1141/1141 [==============================] - 0s 99us/step - loss: 8.5536 - policy_loss: 2.3465 - value_loss: 0.6207 - policy_acc: 0.3725 - value_acc: 0.6082 - val_loss: 9.4888 - val_policy_loss: 3.7173 - val_value_loss: 0.5771 - val_policy_acc: 0.0911 - val_value_acc: 0.6250
# Finished loading 20 training files and 10 validation files
# Train on 1056 samples, validate on 432 samples
# Epoch 1/1
# 1056/1056 [==============================] - 0s 107us/step - loss: 8.1562 - policy_loss: 2.8967 - value_loss: 0.5259 - policy_acc: 0.3040 - value_acc: 0.7216 - val_loss: 9.8336 - val_policy_loss: 4.3041 - val_value_loss: 0.5530 - val_policy_acc: 0.0972 - val_value_acc: 0.6458
# Finished loading 20 training files and 10 validation files
# Train on 1009 samples, validate on 432 samples
# Epoch 1/1
# 1009/1009 [==============================] - 0s 106us/step - loss: 9.5896 - policy_loss: 2.8779 - value_loss: 0.6712 - policy_acc: 0.2706 - value_acc: 0.5738 - val_loss: 9.6206 - val_policy_loss: 4.3749 - val_value_loss: 0.5246 - val_policy_acc: 0.1134 - val_value_acc: 0.6759
# Finished loading 20 training files and 10 validation files
# Train on 1025 samples, validate on 492 samples
# Epoch 1/1
# 1025/1025 [==============================] - 0s 114us/step - loss: 8.4027 - policy_loss: 2.6984 - value_loss: 0.5704 - policy_acc: 0.3180 - value_acc: 0.6985 - val_loss: 9.5757 - val_policy_loss: 4.0751 - val_value_loss: 0.5501 - val_policy_acc: 0.1220 - val_value_acc: 0.6687
# Finished loading 20 training files and 10 validation files
# Train on 1144 samples, validate on 476 samples
# Epoch 1/1
# 1144/1144 [==============================] - 0s 102us/step - loss: 8.5145 - policy_loss: 2.9434 - value_loss: 0.5571 - policy_acc: 0.2526 - value_acc: 0.7089 - val_loss: 9.3710 - val_policy_loss: 4.0725 - val_value_loss: 0.5298 - val_policy_acc: 0.0924 - val_value_acc: 0.6933
# Finished loading 20 training files and 10 validation files
# Train on 1130 samples, validate on 545 samples
# Epoch 1/1
# 1130/1130 [==============================] - 0s 111us/step - loss: 9.0677 - policy_loss: 2.5217 - value_loss: 0.6546 - policy_acc: 0.3319 - value_acc: 0.6071 - val_loss: 8.9156 - val_policy_loss: 3.4594 - val_value_loss: 0.5456 - val_policy_acc: 0.1284 - val_value_acc: 0.6734
# Finished loading 20 training files and 10 validation files
# Train on 1053 samples, validate on 545 samples
# Epoch 1/1
# 1053/1053 [==============================] - 0s 116us/step - loss: 8.6098 - policy_loss: 2.3349 - value_loss: 0.6275 - policy_acc: 0.3286 - value_acc: 0.5575 - val_loss: 8.3452 - val_policy_loss: 3.2517 - val_value_loss: 0.5094 - val_policy_acc: 0.2642 - val_value_acc: 0.7064
# Finished loading 20 training files and 10 validation files
# Train on 1155 samples, validate on 545 samples
# Epoch 1/1
# 1155/1155 [==============================] - 0s 106us/step - loss: 8.5795 - policy_loss: 2.5079 - value_loss: 0.6072 - policy_acc: 0.3074 - value_acc: 0.6442 - val_loss: 8.2664 - val_policy_loss: 3.0015 - val_value_loss: 0.5265 - val_policy_acc: 0.3450 - val_value_acc: 0.6789
# Finished loading 20 training files and 10 validation files
# Train on 1020 samples, validate on 584 samples
# Epoch 1/1
# 1020/1020 [==============================] - 0s 112us/step - loss: 7.2378 - policy_loss: 2.6769 - value_loss: 0.4561 - policy_acc: 0.3392 - value_acc: 0.8078 - val_loss: 9.2305 - val_policy_loss: 2.8220 - val_value_loss: 0.6409 - val_policy_acc: 0.3664 - val_value_acc: 0.6199
# Finished loading 20 training files and 10 validation files
# Train on 1115 samples, validate on 584 samples
# Epoch 1/1
# 1115/1115 [==============================] - 0s 104us/step - loss: 8.5767 - policy_loss: 2.6203 - value_loss: 0.5956 - policy_acc: 0.3794 - value_acc: 0.7049 - val_loss: 8.8039 - val_policy_loss: 2.7034 - val_value_loss: 0.6101 - val_policy_acc: 0.3527 - val_value_acc: 0.6164
# Finished loading 20 training files and 10 validation files
# Train on 1087 samples, validate on 584 samples
# Epoch 1/1
# 1087/1087 [==============================] - 0s 107us/step - loss: 8.2858 - policy_loss: 2.4233 - value_loss: 0.5862 - policy_acc: 0.3487 - value_acc: 0.6164 - val_loss: 8.2318 - val_policy_loss: 2.9098 - val_value_loss: 0.5322 - val_policy_acc: 0.2517 - val_value_acc: 0.6884
# Finished loading 20 training files and 10 validation files
# Train on 1068 samples, validate on 584 samples
# Epoch 1/1
# 1068/1068 [==============================] - 0s 109us/step - loss: 8.7068 - policy_loss: 2.6484 - value_loss: 0.6058 - policy_acc: 0.3343 - value_acc: 0.6217 - val_loss: 8.3391 - val_policy_loss: 2.9823 - val_value_loss: 0.5357 - val_policy_acc: 0.1901 - val_value_acc: 0.6969
# Finished loading 20 training files and 10 validation files
# Train on 1096 samples, validate on 600 samples
# Epoch 1/1
# 1096/1096 [==============================] - 0s 111us/step - loss: 7.5416 - policy_loss: 2.6975 - value_loss: 0.4844 - policy_acc: 0.2947 - value_acc: 0.8239 - val_loss: 9.6877 - val_policy_loss: 2.8536 - val_value_loss: 0.6834 - val_policy_acc: 0.2000 - val_value_acc: 0.6183
# Finished loading 20 training files and 10 validation files
# Train on 1086 samples, validate on 596 samples
# Epoch 1/1
# 1086/1086 [==============================] - 0s 105us/step - loss: 9.0881 - policy_loss: 3.1292 - value_loss: 0.5959 - policy_acc: 0.2726 - value_acc: 0.6519 - val_loss: 10.3697 - val_policy_loss: 3.1442 - val_value_loss: 0.7225 - val_policy_acc: 0.2567 - val_value_acc: 0.5973
# Finished loading 20 training files and 10 validation files
# Train on 1030 samples, validate on 596 samples
# Epoch 1/1
# 1030/1030 [==============================] - 0s 109us/step - loss: 9.0606 - policy_loss: 2.5762 - value_loss: 0.6484 - policy_acc: 0.3175 - value_acc: 0.6311 - val_loss: 9.1450 - val_policy_loss: 2.6012 - val_value_loss: 0.6544 - val_policy_acc: 0.3557 - val_value_acc: 0.5789
# Finished loading 20 training files and 10 validation files
# Train on 1038 samples, validate on 596 samples
# Epoch 1/1
# 1038/1038 [==============================] - 0s 111us/step - loss: 9.2886 - policy_loss: 3.2660 - value_loss: 0.6023 - policy_acc: 0.2158 - value_acc: 0.6195 - val_loss: 9.1937 - val_policy_loss: 2.6287 - val_value_loss: 0.6565 - val_policy_acc: 0.3322 - val_value_acc: 0.5789
# Finished loading 20 training files and 10 validation files
# Train on 1030 samples, validate on 556 samples
# Epoch 1/1
# 1030/1030 [==============================] - 0s 115us/step - loss: 8.3728 - policy_loss: 2.6777 - value_loss: 0.5695 - policy_acc: 0.3155 - value_acc: 0.6757 - val_loss: 9.6394 - val_policy_loss: 2.7570 - val_value_loss: 0.6882 - val_policy_acc: 0.3453 - val_value_acc: 0.5522
# Finished loading 20 training files and 10 validation files
# Train on 1105 samples, validate on 476 samples
# Epoch 1/1
# 1105/1105 [==============================] - 0s 103us/step - loss: 8.2882 - policy_loss: 2.6708 - value_loss: 0.5617 - policy_acc: 0.3186 - value_acc: 0.6661 - val_loss: 8.6754 - val_policy_loss: 2.2059 - val_value_loss: 0.6469 - val_policy_acc: 0.3424 - val_value_acc: 0.5798
# Finished loading 20 training files and 10 validation files
# Train on 1062 samples, validate on 426 samples
# Epoch 1/1
# 1062/1062 [==============================] - 0s 103us/step - loss: 8.4086 - policy_loss: 2.9290 - value_loss: 0.5480 - policy_acc: 0.3098 - value_acc: 0.7034 - val_loss: 8.5801 - val_policy_loss: 2.6209 - val_value_loss: 0.5959 - val_policy_acc: 0.3122 - val_value_acc: 0.6244
# Finished loading 20 training files and 10 validation files
# Train on 1095 samples, validate on 426 samples
# Epoch 1/1
# 1095/1095 [==============================] - 0s 109us/step - loss: 8.4215 - policy_loss: 2.3567 - value_loss: 0.6065 - policy_acc: 0.3863 - value_acc: 0.6849 - val_loss: 7.8737 - val_policy_loss: 2.8622 - val_value_loss: 0.5012 - val_policy_acc: 0.2160 - val_value_acc: 0.7394
# Finished loading 20 training files and 10 validation files
# Train on 1109 samples, validate on 426 samples
# Epoch 1/1
# 1109/1109 [==============================] - 0s 122us/step - loss: 8.5770 - policy_loss: 2.2912 - value_loss: 0.6286 - policy_acc: 0.3751 - value_acc: 0.5437 - val_loss: 7.7840 - val_policy_loss: 2.8262 - val_value_loss: 0.4958 - val_policy_acc: 0.3075 - val_value_acc: 0.7488

# %%
import matplotlib.pyplot as plt 
    
plt.figure(1, figsize=(18, 18))
   
# summarize history for accuracy  
   
plt.subplot(211)  
# plt.plot(history.history['policy_acc'])  
plt.plot(historyPolicyValAcc)  
# plt.plot(history.history['value_acc'])  
plt.plot(historyValueValAcc)  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
# plt.legend(['policy_categorical_accuracy', 'val_policy_categorical_accuracy', 'value_categorical_accuracy', 'val_value_categorical_accuracy'], loc='upper left')  
plt.legend(['Validation Policy Accuracy','Validation Value Accuracy'], loc='upper left')  
   
# summarize history for loss  
   
plt.subplot(212)  
plt.plot(historyPolicyValLoss)  
plt.plot([x * 10 for x in historyValueValLoss])  
plt.plot(historyValLoss)   
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
# plt.legend(['policy_loss', 'val_policy_loss', 'value_loss','val_value_loss','loss','val_loss',], loc='upper left')  
plt.legend(['val_policy_loss','val_value_loss','val_loss'], loc='upper left')  

plt.show()

# %%
# save model and proceed to next iteration

import re
from os import listdir
from os.path import isfile, join

# find highest iteration model 

filepath = '.'

onlyFiles = [f for f in listdir(filepath) if isfile(join(filepath, f)) and 'iter' in f]
highestIteration = max([int(re.findall(r'\d+', filename)[0]) for filename in onlyFiles], key=lambda iterNum: int(iterNum))

newModelFileName = 'gz_dev.iter{0}.model'.format(highestIteration + 1)
print(newModelFileName)

model.save("gz_dev.model")
model.save(newModelFileName)
# Out:
# gz_dev.iter1.model

# %%
from trainingGame import loadTrainingGame
from trainingHelper import TrainingHelper
from mapHelper import mapHelper

game = loadTrainingGame("testGame.pickle")
exampleState = game.states[0]
mapHelper.setItems(exampleState)
helper = TrainingHelper(game) 

trainX = helper.getTrainX()

# %%
print(trainX[299])
# Out:
# [[ 0.          1.          0.          0.          0.5         0.
#    0.24       -2.08        0.32        0.          0.          0.
#    0.          0.          0.        ]
#  [ 0.          0.67        0.          0.          0.          0.
#    0.19       -1.52        0.1         0.06       -1.38        0.065
#    0.          0.          0.        ]
#  [ 0.          0.62        0.          0.          1.88        0.
#    0.18       -1.46       -1.29        0.          0.          0.
#    0.01       -1.11       -1.12      ]
#  [ 0.          0.58        0.          0.          0.02        0.
#    0.18       -1.45        1.32        0.          0.          0.
#    0.          0.          0.        ]
#  [ 0.95        0.          0.          0.01        0.          0.
#    0.23       -1.37       -0.72        0.          0.          0.
#    0.          0.          0.        ]
#  [ 0.          0.          0.34        0.          0.          0.17
#    0.14       -1.07        0.3         0.08       -1.11875     0.055
#    0.02       -1.25        0.345     ]
#  [ 0.          0.27        0.          0.          0.22        0.
#    0.13       -0.98       -1.38        0.          0.          0.
#    0.03       -0.89666667 -1.24      ]
#  [ 0.          0.62        0.          0.          0.81        0.
#    0.18       -0.94        1.22        0.01       -0.7         1.03
#    0.14       -0.885       1.02      ]
#  [ 0.          0.          0.57        0.          0.          0.04
#    0.17       -0.44       -0.13        0.03       -0.48       -0.23
#    0.04       -0.445       0.0575    ]
#  [ 0.15        0.          0.          0.          0.          0.
#    0.12       -0.21        0.25        0.04       -0.16        0.0025
#    0.09       -0.16444444  0.49333333]
#  [ 0.          0.          0.22        0.          0.          0.21
#    0.12       -0.14        1.39        0.01       -0.08        1.16
#    0.          0.          0.        ]
#  [ 0.          0.          0.22        0.          0.          0.43
#    0.12        0.14       -1.39        0.11       -0.05       -1.03
#    0.05        0.058      -1.372     ]
#  [ 0.15        0.          0.          0.04        0.          0.
#    0.12        0.21       -0.25        0.02        0.205      -0.245
#    0.          0.          0.        ]
#  [ 0.57        0.          0.          0.          0.          0.
#    0.17        0.44        0.13        0.06        0.63166667 -0.11666667
#    0.11        0.56        0.04363636]
#  [ 0.          0.          0.62        0.          0.          0.2
#    0.18        0.94       -1.22        0.          0.          0.
#    0.          0.          0.        ]
#  [ 0.          0.27        0.          0.          0.01        0.
#    0.13        0.98        1.38        0.          0.          0.
#    0.          0.          0.        ]
#  [ 0.          0.          0.34        0.          0.          0.31
#    0.14        1.07       -0.3         0.03        1.16333333 -0.20333333
#    0.02        0.91       -0.055     ]
#  [ 0.          0.          0.95        0.          0.          0.29
#    0.23        1.37        0.72        0.01        1.8         0.4
#    0.          0.          0.        ]
#  [ 0.          0.58        0.          0.          0.04        0.
#    0.18        1.45       -1.32        0.          0.          0.
#    0.          0.          0.        ]
#  [ 0.          0.          0.62        0.          0.          0.06
#    0.18        1.46        1.29        0.          0.          0.
#    0.          0.          0.        ]
#  [ 0.          0.67        0.          0.          0.02        0.
#    0.19        1.52       -0.1         0.03        1.50666667 -0.33333333
#    0.          0.          0.        ]
#  [ 1.          0.          0.          0.01        0.          0.
#    0.24        2.08       -0.32        0.          0.          0.
#    0.          0.          0.        ]]

# %%
import numpy as np
a = model.predict(np.array([trainX[0]]))
a[1][0][0]
# Out:
# 0.62095207
